# %% [markdown]
# # huchlab/singlecell-notebook on Binder
#
# Run the cells below to inspect what's in the [singlecell-notebook](https://sequencing-docker-stacks.readthedocs.io) image from the Sequencing Docker Stacks project.
#
# You can launch the classic notebook interface in Binder by replacing `lab/tree/*` with `tree/` in the JupyterLab URL.

# %%
import os

import scanpy as sc

# %%
print(
    f"This container is using tag {os.environ['TAG']} of the huchlab/singlecell-notebook image"
)

# %% [markdown]
# Basic single cell analysis:

# %%
adata = sc.datasets.pbmc3k_processed()

# %%
sc.pl.umap(adata, color="louvain")

# %% [markdown]
# The Server is running as the following user.

# %%
# !id

# %% [markdown]
# Here's the contents of that user's home directory, the default notebook directory for the server.

# %%
# !ls -al

# %% [markdown]
# `mamba` is available in the user's path.

# %%
# !which mamba

# %% [markdown]
# The user has read/write access to the root mamba environment.

# %%
# !ls -l /opt/conda

# %% [markdown]
# The following packages are mamba-installed in the singlecell-notebook image:

# %%
# !mamba list

# %% [markdown]
# Other images in the [sequencing-docker-stacks](https://github.com/huchlab/sequencing-docker-stacks) include different libraries. See the [Sequencing Docker Stacks documentation](https://sequencing-docker-stacks.readthedocs.io/en/latest/) for full details.
